# %%
import torch
from torch import Tensor
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid

dataset = Planetoid(root='.', name='Cora')

class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x: Tensor, edge_index: Tensor) -> Tensor:
        # x: Node feature matrix of shape [num_nodes, in_channels]
        # edge_index: Graph connectivity matrix of shape [2, num_edges]
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

model = GCN(dataset.num_features, 16, dataset.num_classes)
# Out:
# /Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: dlopen(/Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <CA14ED34-FA3D-31FE-B4AD-2B2A8446B324> /Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: dlopen(/Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <CA14ED34-FA3D-31FE-B4AD-2B2A8446B324> /Users/michaels/anaconda3/envs/icgnn/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
import torch.nn.functional as F

data = dataset[0]
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(200):
    pred = model(data.x, data.edge_index)
    loss = F.cross_entropy(pred[data.train_mask], data.y[data.train_mask])

    # Backpropagation
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 1.9494
# Epoch 2, Loss: 1.8339
# Epoch 3, Loss: 1.7062
# Epoch 4, Loss: 1.5566
# Epoch 5, Loss: 1.4026
# Epoch 6, Loss: 1.2627
# Epoch 7, Loss: 1.1327
# Epoch 8, Loss: 1.0061
# Epoch 9, Loss: 0.8843
# Epoch 10, Loss: 0.7701
# Epoch 11, Loss: 0.6664
# Epoch 12, Loss: 0.5740
# Epoch 13, Loss: 0.4920
# Epoch 14, Loss: 0.4198
# Epoch 15, Loss: 0.3566
# Epoch 16, Loss: 0.3018
# Epoch 17, Loss: 0.2548
# Epoch 18, Loss: 0.2151
# Epoch 19, Loss: 0.1819
# Epoch 20, Loss: 0.1541
# Epoch 21, Loss: 0.1310
# Epoch 22, Loss: 0.1117
# Epoch 23, Loss: 0.0954
# Epoch 24, Loss: 0.0816
# Epoch 25, Loss: 0.0701
# Epoch 26, Loss: 0.0605
# Epoch 27, Loss: 0.0525
# Epoch 28, Loss: 0.0457
# Epoch 29, Loss: 0.0401
# Epoch 30, Loss: 0.0353
# Epoch 31, Loss: 0.0312
# Epoch 32, Loss: 0.0277
# Epoch 33, Loss: 0.0248
# Epoch 34, Loss: 0.0223
# Epoch 35, Loss: 0.0201
# Epoch 36, Loss: 0.0182
# Epoch 37, Loss: 0.0166
# Epoch 38, Loss: 0.0152
# Epoch 39, Loss: 0.0139
# Epoch 40, Loss: 0.0128
# Epoch 41, Loss: 0.0119
# Epoch 42, Loss: 0.0110
# Epoch 43, Loss: 0.0103
# Epoch 44, Loss: 0.0096
# Epoch 45, Loss: 0.0090
# Epoch 46, Loss: 0.0085
# Epoch 47, Loss: 0.0080
# Epoch 48, Loss: 0.0075
# Epoch 126, Loss: 0.0017
# Epoch 127, Loss: 0.0017
# Epoch 128, Loss: 0.0016
# Epoch 129, Loss: 0.0016
# Epoch 130, Loss: 0.0016
# Epoch 131, Loss: 0.0016
# Epoch 132, Loss: 0.0016
# Epoch 133, Loss: 0.0016
# Epoch 134, Loss: 0.0015
# Epoch 135, Loss: 0.0015
# Epoch 136, Loss: 0.0015
# Epoch 137, Loss: 0.0015
# Epoch 138, Loss: 0.0015
# Epoch 139, Loss: 0.0015
# Epoch 140, Loss: 0.0015
# Epoch 141, Loss: 0.0014
# Epoch 142, Loss: 0.0014
# Epoch 143, Loss: 0.0014
# Epoch 144, Loss: 0.0014
# Epoch 145, Loss: 0.0014
# Epoch 146, Loss: 0.0014
# Epoch 147, Loss: 0.0014
# Epoch 148, Loss: 0.0014
# Epoch 149, Loss: 0.0013
# Epoch 150, Loss: 0.0013
# Epoch 151, Loss: 0.0013
# Epoch 152, Loss: 0.0013
# Epoch 153, Loss: 0.0013
# Epoch 154, Loss: 0.0013
# Epoch 155, Loss: 0.0013
# Epoch 156, Loss: 0.0013
# Epoch 157, Loss: 0.0013
# Epoch 158, Loss: 0.0012
# Epoch 159, Loss: 0.0012
# Epoch 160, Loss: 0.0012
# Epoch 161, Loss: 0.0012
# Epoch 162, Loss: 0.0012
# Epoch 163, Loss: 0.0012
# Epoch 164, Loss: 0.0012
# Epoch 165, Loss: 0.0012
# Epoch 166, Loss: 0.0012
# Epoch 167, Loss: 0.0011
# Epoch 168, Loss: 0.0011
# Epoch 169, Loss: 0.0011
# Epoch 170, Loss: 0.0011
# Epoch 171, Loss: 0.0011
# Epoch 172, Loss: 0.0011
# Epoch 173, Loss: 0.0011
# Epoch 174, Loss: 0.0011
# Epoch 175, Loss: 0.0011
# Epoch 176, Loss: 0.0011
# Epoch 177, Loss: 0.0011
# Epoch 178, Loss: 0.0011
# Epoch 179, Loss: 0.0010
# Epoch 180, Loss: 0.0010
# Epoch 181, Loss: 0.0010
# Epoch 182, Loss: 0.0010
# Epoch 183, Loss: 0.0010
# Epoch 184, Loss: 0.0010
# Epoch 185, Loss: 0.0010
# Epoch 186, Loss: 0.0010
# Epoch 187, Loss: 0.0010
# Epoch 188, Loss: 0.0010
# Epoch 189, Loss: 0.0010
# Epoch 190, Loss: 0.0010
# Epoch 191, Loss: 0.0009
# Epoch 192, Loss: 0.0009
# Epoch 193, Loss: 0.0009
# Epoch 194, Loss: 0.0009
# Epoch 195, Loss: 0.0009
# Epoch 196, Loss: 0.0009
# Epoch 197, Loss: 0.0009
# Epoch 198, Loss: 0.0009
# Epoch 199, Loss: 0.0009
# Epoch 200, Loss: 0.0009

# %%
type(dataset)
# Out:
# torch_geometric.datasets.planetoid.Planetoid
